# %% [markdown]
# <a href="https://colab.research.google.com/github/BilG7/Images/blob/main/cnn_pomme_poire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Mon CNN pomme/poire démarre")
# Out:
# Mon CNN pomme/poire démarre

# %%
import tensorflow as tf
from tensorflow import keras

print("TensorFlow version :", tf.__version__)
# Out:
# TensorFlow version : 2.19.0

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

dataset = image_dataset_from_directory(
    "/content/dataset",
    image_size=(128, 128),
    batch_size=32
)
# Out:
# Found 2210 files belonging to 2 classes.

# %%
import zipfile

with zipfile.ZipFile('/content/dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
dataset = image_dataset_from_directory(
    "/content/dataset",
    image_size=(128, 128),
    batch_size=32
)
# Out:
# Found 2210 files belonging to 2 classes.

# %%
import os
print(os.listdir('/content/dataset'))
# Out:
# ['pomme', 'poire']

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(128, 128, 3)),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(49, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(49, activation='relu'),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dense(7, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(dataset, epochs=50)
# Out:
# Epoch 1/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 49s 699ms/step - accuracy: 0.6783 - loss: 0.5553
# Epoch 2/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 49s 701ms/step - accuracy: 0.7452 - loss: 0.5006
# Epoch 3/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 49s 695ms/step - accuracy: 0.7679 - loss: 0.4631
# Epoch 4/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 50s 705ms/step - accuracy: 0.7900 - loss: 0.4393
# Epoch 5/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 81s 696ms/step - accuracy: 0.8376 - loss: 0.3650
# Epoch 6/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 82s 702ms/step - accuracy: 0.8335 - loss: 0.3665
# Epoch 7/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 49s 699ms/step - accuracy: 0.8891 - loss: 0.2675
# Epoch 8/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 82s 703ms/step - accuracy: 0.9131 - loss: 0.2155
# Epoch 9/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 82s 702ms/step - accuracy: 0.9439 - loss: 0.1498
# Epoch 10/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 82s 702ms/step - accuracy: 0.9557 - loss: 0.1163
# Epoch 11/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 82s 704ms/step - accuracy: 0.9796 - loss: 0.0660
# Epoch 12/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 49s 704ms/step - accuracy: 0.9796 - loss: 0.0595
# Epoch 13/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 83s 716ms/step - accuracy: 0.9814 - loss: 0.0545
# Epoch 14/50
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 49s 701ms/step - accuracy: 0.9747 - loss: 0.0760
# Epoch 15/50
# 20/70 ━━━━━━━━━━━━━━━━━━━━ 36s 723ms/step - accuracy: 0.9783 - loss: 0.0765

# %%
class_names = dataset.class_names
print(class_names)

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

img_path = "/content/testpommepoire/poire/r2_99_100.jpg"

img = load_img(img_path, target_size=(128, 128))
img_array = img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)
print("Prédiction brute :", prediction)

classe_predite = class_names[np.argmax(prediction)]
print("Classe prédite :", classe_predite)
print("Confiance :", np.max(prediction) * 100, "%")
